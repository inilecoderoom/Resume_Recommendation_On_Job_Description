# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import os

# import fitz
# from PyPDF2 import PdfReader

import sys
from pyresparser import ResumeParser

import torch as tr
from transformers import DistilBertModel, DistilBertTokenizer

from sklearn.metrics.pairwise import cosine_similarity
# sys.executable

# %%
resume_data = "./Resume-Data/data/"
skills_data = "./Resume-Data/skills.csv"
job_data = "./Resume-Data/training_data.csv"

# %%
def embedding_text(text):
    tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-cased')
    model = DistilBertModel.from_pretrained("distilbert-base-cased")
    encoded_dict = tokenizer.encode_plus(
                            text,                      
                            add_special_tokens = True, 
                            max_length = 64,           
                            pad_to_max_length = True,
                            return_attention_mask = True,   
                            return_tensors = 'pt',    
                            truncation = True
                       )
    output = model(encoded_dict['input_ids'],encoded_dict['attention_mask'])
    return output

# %%
path = [os.path.join(resume_data,i) for i in os.listdir(resume_data)]
path_list = [os.path.join(items, x).replace("\\","/") for items in path for x in os.listdir(items)]
res_data = []
for i in range(len(path_list)):
# for i in range(10):
    data = ResumeParser(path_list[i]).get_extracted_data()
    res_data.append([path_list[i].split('/')[-1].split('.')[0], data['name'], (" ".join(data['skills'])).strip(","), path_list[i]])

res_data = pd.DataFrame(res_data, columns = ['Res_id','Position','Skills', 'Path'])
res_data

# %%
len(res_data)
# Out:
# 10

# %%
jd = pd.read_csv(job_data)
jd['job_description']
# Out:
# 0      minimum qualifications\nbachelors degree or eq...
# 1      description\nas an asc you will be highly infl...
# 2      its an amazing time to be joining netflix as w...
# 3      description\n\nweb designers looking to expand...
# 4      at trackfive weve got big goals were on a miss...
#                              ...
# 848    job description\n\nparttime\n\nmake big money ...
# 849    responsibilities\nparkers internship program w...
# 850     the borgen project is an innovative national ...
# 851    put the world on vacation\n\nat wyndham destin...
# 852    this job handles customer inquiries by telepho...
# Name: job_description, Length: 853, dtype: object

# %%
# jd['job_description'].sample(10)

# %%
import re
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nilesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
skills_list = pd.read_csv(skills_data)
skills_list = skills_list.columns
skills_list
# Out:
# Index(['technical skills', 'ajenti', 'django-suit', 'django-xadmin',
#        'flask-admin', 'flower', 'grappelli', 'wooey', 'algorithms',
#        'pypattyrn',
#        ...
#        'virtualized networks', 'network automation', 'cloud management', 'ai',
#        'salesforce', 'mango db', 'math', 'calculus', 'product launch', 'mvp'],
#       dtype='object', length=1249)

# %%
# Lower case
jd['clean_job_description'] = jd['job_description'].apply(lambda x: " ".join(x.lower()for x in x.split()))
# remove tabulation and punctuation
jd['clean_job_description'] = jd['clean_job_description'].str.replace('[^\w\s]',' ')
## digits
jd['clean_job_description'] = jd['clean_job_description'].str.replace('\d+', '')

#remove stop words
jd['clean_job_description'] = jd['clean_job_description'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words))

## lemmatization
# jd['job_description'] = jd['job_description'].apply(lambda x: " ".join([wordnet_lemmatizer.lemmatize(word) for word in x.split()]))

jd['clean_job_description'] = jd['clean_job_description'].apply(lambda x: " ".join([word for word in x.split() if word in skills_list]))

# %%
# ## Delete more stop words
# other_stop_words = ['junior', 'senior','experience','etc','job','work','company','technique',
#                     'candidate','skill','skills','language','menu','inc','new','plus','years',
#                    'technology','organization','ceo','cto','account','manager','data','scientist','mobile',
#                     'developer','product','revenue','strong', 'description', 'qualification', 'minimum', 'maximum', 'joining', 'amazing']

# jd['job_description'] = jd['job_description'].apply(lambda x: " ".join(x for x in x.split() if x not in other_stop_words))

# %%
jd.head()
# Out:
#   company_name                                    job_description  \
# 0       Google  minimum qualifications\nbachelors degree or eq...
# 1        Apple  description\nas an asc you will be highly infl...
# 2      Netflix  its an amazing time to be joining netflix as w...
# 3  Robert Half  description\n\nweb designers looking to expand...
# 4    TrackFive  at trackfive weve got big goals were on a miss...
#
#                               position_title  description_length  \
# 0                           Sales Specialist                2727
# 1                 Apple Solutions Consultant                 828
# 2  Licensing Coordinator - Consumer Products                3205
# 3                               Web Designer                2489
# 4                              Web Developer                3167
#
#                                       model_response  \
# 0   {\n  "Core Responsibilities": "Responsible fo...
# 1   {\n  "Core Responsibilities": "as an asc you ...
# 2   {\n  "Core Responsibilities": "Help drive bus...
# 3   {\n  "Core Responsibilities": "Designing webs...
# 4   {\n  "Core Responsibilities": "Build and layo...
#
#                                clean_job_description
# 0  saas sales partnerships plan communication clo...
# 1           visual merchandising communication sales
# 2  tv content partnerships licensing content cont...
# 3  marketing process brand mobile interactive tes...
# 4  recruiting blaze startup process lifecycle cod...

# %%
recommended_data = []
for l in range(15):
    em1 = np.squeeze(embedding_text(jd['clean_job_description'][l])[0].detach().numpy())
    for i in range(len(res_data)):
        # score_list = []
        # recommended_data.append(i)
        em2 = np.squeeze(embedding_text(res_data['Skills'][i])[0].detach().numpy())
        similarity_score = cosine_similarity(em1, em2)
        score = similarity_score.mean()
        recommended_data.append([jd['job_description'][l], res_data['Path'][i], score])

# %%
res_df = pd.DataFrame(recommended_data, columns = ['Job_Description','Resume_Path','Score'])
res_df
# Out:
#                                       Job_Description  \
# 0   minimum qualifications\nbachelors degree or eq...
# 1   minimum qualifications\nbachelors degree or eq...
# 2   minimum qualifications\nbachelors degree or eq...
# 3   minimum qualifications\nbachelors degree or eq...
# 4   minimum qualifications\nbachelors degree or eq...
# ..                                                ...
# 95  type of requisition regular\n\nclearance level...
# 96  type of requisition regular\n\nclearance level...
# 97  type of requisition regular\n\nclearance level...
# 98  type of requisition regular\n\nclearance level...
# 99  type of requisition regular\n\nclearance level...
#
#                                    Resume_Path     Score
# 0   ./Resume-Data/data/ACCOUNTANT/10554236.pdf  0.663024
# 1   ./Resume-Data/data/ACCOUNTANT/10674770.pdf  0.656870
# 2   ./Resume-Data/data/ACCOUNTANT/11163645.pdf  0.682992
# 3   ./Resume-Data/data/ACCOUNTANT/11759079.pdf  0.674160
# 4   ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.688330
# ..                                         ...       ...
# 95  ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.637351
# 96  ./Resume-Data/data/ACCOUNTANT/12338274.pdf  0.622540
# 97  ./Resume-Data/data/ACCOUNTANT/12442909.pdf  0.612729
# 98  ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.635038
# 99  ./Resume-Data/data/ACCOUNTANT/12802330.pdf  0.636252
#
# [100 rows x 3 columns]

# %%
# res_df.groupby('Job_Description').apply(lambda x: x.sort_values(["Score"], ascending = False)).reset_index(drop=True)
# Out:
#                                       Job_Description  \
# 0   about the position\n\nthe web designer is resp...
# 1   about the position\n\nthe web designer is resp...
# 2   about the position\n\nthe web designer is resp...
# 3   about the position\n\nthe web designer is resp...
# 4   about the position\n\nthe web designer is resp...
# ..                                                ...
# 95  type of requisition regular\n\nclearance level...
# 96  type of requisition regular\n\nclearance level...
# 97  type of requisition regular\n\nclearance level...
# 98  type of requisition regular\n\nclearance level...
# 99  type of requisition regular\n\nclearance level...
#
#                                    Resume_Path     Score
# 0   ./Resume-Data/data/ACCOUNTANT/10554236.pdf  0.627723
# 1   ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.627545
# 2   ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.625108
# 3   ./Resume-Data/data/ACCOUNTANT/12802330.pdf  0.623151
# 4   ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.621724
# ..                                         ...       ...
# 95  ./Resume-Data/data/ACCOUNTANT/11759079.pdf  0.629078
# 96  ./Resume-Data/data/ACCOUNTANT/11163645.pdf  0.627468
# 97  ./Resume-Data/data/ACCOUNTANT/10674770.pdf  0.625511
# 98  ./Resume-Data/data/ACCOUNTANT/12338274.pdf  0.622540
# 99  ./Resume-Data/data/ACCOUNTANT/12442909.pdf  0.612729
#
# [100 rows x 3 columns]

# %%
final_df = res_df.sort_values(['Job_Description', 'Score'],ascending=False).groupby('Job_Description').head(5)
final_df
# Out:
#                                       Job_Description  \
# 94  type of requisition regular\n\nclearance level...
# 95  type of requisition regular\n\nclearance level...
# 90  type of requisition regular\n\nclearance level...
# 99  type of requisition regular\n\nclearance level...
# 98  type of requisition regular\n\nclearance level...
# 84  tuff is a growth marketing team working with c...
# 88  tuff is a growth marketing team working with c...
# 80  tuff is a growth marketing team working with c...
# 85  tuff is a growth marketing team working with c...
# 89  tuff is a growth marketing team working with c...
# 4   minimum qualifications\nbachelors degree or eq...
# 8   minimum qualifications\nbachelors degree or eq...
# 2   minimum qualifications\nbachelors degree or eq...
# 5   minimum qualifications\nbachelors degree or eq...
# 3   minimum qualifications\nbachelors degree or eq...
# 74  job description\n\nzander insurance group is o...
# 78  job description\n\nzander insurance group is o...
# 75  job description\n\nzander insurance group is o...
# 72  job description\n\nzander insurance group is o...
# 76  job description\n\nzander insurance group is o...
# 24  its an amazing time to be joining netflix as w...
# 28  its an amazing time to be joining netflix as w...
# 20  its an amazing time to be joining netflix as w...
# 29  its an amazing time to be joining netflix as w...
# 25  its an amazing time to be joining netflix as w...
# 54  designups is a nashville based design and inte...
# 58  designups is a nashville based design and inte...
# 52  designups is a nashville based design and inte...
# 55  designups is a nashville based design and inte...
# 53  designups is a nashville based design and inte...
# 14  description\nas an asc you will be highly infl...
# 18  description\nas an asc you will be highly infl...
# 12  description\nas an asc you will be highly infl...
# 15  description\nas an asc you will be highly infl...
# 17  description\nas an asc you will be highly infl...
# 34  description\n\nweb designers looking to expand...
# 38  description\n\nweb designers looking to expand...
# 35  description\n\nweb designers looking to expand...
# 39  description\n\nweb designers looking to expand...
# 32  description\n\nweb designers looking to expand...
# 44  at trackfive weve got big goals were on a miss...
# 48  at trackfive weve got big goals were on a miss...
# 42  at trackfive weve got big goals were on a miss...
# 40  at trackfive weve got big goals were on a miss...
# 45  at trackfive weve got big goals were on a miss...
# 60  about the position\n\nthe web designer is resp...
# 64  about the position\n\nthe web designer is resp...
# 65  about the position\n\nthe web designer is resp...
# 69  about the position\n\nthe web designer is resp...
# 68  about the position\n\nthe web designer is resp...
#
#                                    Resume_Path     Score
# 94  ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.641517
# 95  ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.637351
# 90  ./Resume-Data/data/ACCOUNTANT/10554236.pdf  0.637283
# 99  ./Resume-Data/data/ACCOUNTANT/12802330.pdf  0.636252
# 98  ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.635038
# 84  ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.586827
# 88  ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.586509
# 80  ./Resume-Data/data/ACCOUNTANT/10554236.pdf  0.586314
# 85  ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.585919
# 89  ./Resume-Data/data/ACCOUNTANT/12802330.pdf  0.585192
# 4   ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.688330
# 8   ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.684906
# 2   ./Resume-Data/data/ACCOUNTANT/11163645.pdf  0.682992
# 5   ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.674543
# 3   ./Resume-Data/data/ACCOUNTANT/11759079.pdf  0.674160
# 74  ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.694489
# 78  ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.683395
# 75  ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.675823
# 72  ./Resume-Data/data/ACCOUNTANT/11163645.pdf  0.674655
# 76  ./Resume-Data/data/ACCOUNTANT/12338274.pdf  0.674470
# 24  ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.667569
# 28  ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.662774
# 20  ./Resume-Data/data/ACCOUNTANT/10554236.pdf  0.662588
# 29  ./Resume-Data/data/ACCOUNTANT/12802330.pdf  0.659281
# 25  ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.654251
# 54  ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.665128
# 58  ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.652673
# 52  ./Resume-Data/data/ACCOUNTANT/11163645.pdf  0.647072
# 55  ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.645052
# 53  ./Resume-Data/data/ACCOUNTANT/11759079.pdf  0.644748
# 14  ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.685184
# 18  ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.672883
# 12  ./Resume-Data/data/ACCOUNTANT/11163645.pdf  0.670170
# 15  ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.666728
# 17  ./Resume-Data/data/ACCOUNTANT/12442909.pdf  0.664916
# 34  ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.655818
# 38  ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.651597
# 35  ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.645387
# 39  ./Resume-Data/data/ACCOUNTANT/12802330.pdf  0.642490
# 32  ./Resume-Data/data/ACCOUNTANT/11163645.pdf  0.642199
# 44  ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.669143
# 48  ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.668257
# 42  ./Resume-Data/data/ACCOUNTANT/11163645.pdf  0.657996
# 40  ./Resume-Data/data/ACCOUNTANT/10554236.pdf  0.653066
# 45  ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.652458
# 60  ./Resume-Data/data/ACCOUNTANT/10554236.pdf  0.627723
# 64  ./Resume-Data/data/ACCOUNTANT/12065211.pdf  0.627545
# 65  ./Resume-Data/data/ACCOUNTANT/12202337.pdf  0.625108
# 69  ./Resume-Data/data/ACCOUNTANT/12802330.pdf  0.623151
# 68  ./Resume-Data/data/ACCOUNTANT/12780508.pdf  0.621724

# %%
# with open(path_list[0],'rb') as f:
#     reader = PdfReader(f)
# #     info = reader.getDocumentInfo()
# #     print(info)
#     for page in reader.pages:
#         txt = page.extract_text()
        
# doc = fitz.open(path_list[1])
# text = ""
# for page in doc:
#    text+=page.get_text()
